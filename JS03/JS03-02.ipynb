# %% [markdown]
# <a href="https://colab.research.google.com/github/trialdyk/marchine-learning/blob/main/JS03/JS03-02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 2 - Sekilas Ekstraksi Fitur TF-IDF

# %% [markdown]
# ## Langkah 0 - Siapkan Corpus

# %%
corpus = [
    'the house had a tiny little mouse',
    'the cat saw the mouse',
    'the mouse ran away from the house',
    'the cat finally ate the mouse',
    'the end of the mouse story'
]

# %% [markdown]
# ## Langkah 1 - Buat Model TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vect = TfidfVectorizer(stop_words='english')

resp = vect.fit_transform(corpus)

print(resp)

# %% [markdown]
# ## Langkah 2 - Cek Kata yang Digunakan

# %%
print(vect.get_feature_names_out())
